# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
import sqlite3
from konlpy.tag import *
from konlpy.utils import pprint

import pandas as pd

# %%
f = open("C:\\Users\\lee\\Desktop\\02.[텍스트데이터] naver-news\\KB국민은행_20190101_20190331.txt", 'rt',encoding='utf-8')
s = f.read()
#print(s)

# %%
df =pd.read_csv('C:\\Users\\lee\\Desktop\\02.[텍스트데이터] naver-news\\KB국민은행_20190101_20190331.txt', sep='\t', names=['Date','Company','Title','Content'])
df
# Out:
#             Date         Company  \
# 0    2019.03.31.            매경닷컴
# 1    2019.03.30.  financial news
# 2    2019.03.29.             뉴스1
# 3    2019.03.29.            노컷뉴스
# 4    2019.03.29.             머니S
# 5    2019.03.30.             머니S
# 6    2019.03.28.           스포츠동아
# 7    2019.03.27.            서울경제
# 8    2019.03.25.             MBN
# 9    2019.03.26.            세계닷컴
# 10   2019.03.25.           스포츠동아
# 11   2019.03.22.             뉴시스
# 12   2019.03.19.             뉴시스
# 13   2019.02.28.  financial news
# 14   2019.03.19.           스포츠서울
# 15   2019.03.23.  financial news
# 16   2019.03.19.            조세일보
# 17   2019.02.28.           일간스포츠
# 18   2019.03.20.        PRESSian
# 19   2019.02.28.           헤럴드경제
# 20   2019.03.27.     inews24.com
# 21   2019.03.27.          edaily
# 22   2019.03.27.            서울경제
# 23   2019.03.26.          디지털타임스
# 24   2019.03.26.           스포츠서울
# 25   2019.03.26.           스포츠조선
# 26   2019.03.25.          디지털타임스
# 27   2019.03.25.     inews24.com
# 28   2019.03.26.            서울경제
# 29   2019.03.25.           스포츠서울
# ..           ...             ...
# 270  2019.03.05.           스포츠서울
# 271  2019.01.07.             뉴시스
# 272  2019.01.07.             뉴시스
# 273  2019.01.07.             뉴시스
# 274  2019.01.07.             뉴시스
# 275  2019.01.07.             뉴시스
# 276  2019.01.07.             뉴시스
# 277  2019.01.07.             뉴시스
# 278  2019.02.01.            한경닷컴
# 279  2019.01.15.            한국일보
# 280  2019.01.15.         아시아경제신문
# 281  2019.01.08.             뉴스1
# 282  2019.01.23.             뉴시스
# 283  2019.01.08.             뉴스1
# 284  2019.01.08.             뉴스1
# 285  2019.01.08.             뉴스1
# 286  2019.03.12.            서울경제
# 287  2019.01.04.          한국경제TV
# 288  2019.01.04.  financial news
# 289  2019.01.11.          디지털타임스
# 290  2019.01.11.            조세일보
# 291  2019.01.11.            조선비즈
# 292  2019.02.08.     inews24.com
# 293  2019.01.16.             뉴시스
# 294  2019.01.07.            서울신문
# 295  2019.01.17.             뉴시스
# 296  2019.03.04.            조세일보
# 297  2019.03.04.           스포츠서울
# 298  2019.01.08.             KBS
# 299  2019.01.08.            JTBC
#
#                                                  Title  \
# 0                              제5회 퇴직연금 대상, KB국민은행·한수원
# 1                      KB국민은행, 미세먼지 저감을 위한 에코트리 캠페인 진행
# 2                                    인사말 하는 허인 KB국민은행장
# 3                        KB국민은행, 동의대에 대학발전기금 4억5천만원 전달
# 4            원더쇼핑, KB국민은행 뱅킹앱 '리브똑똑'과 투썸아메리카노 '0원' 이벤트
# 20   [아이뉴스24 문병언 기자] KB금융그룹이 홍콩에 이어 런던에 IB Unit을 개설...
# 21   KB국민은행 영국 런던지점에서 26일(현지시간) 열린 ‘런던 IB 유닛’ 개소식에서...
# 22   이계성(오른쪽 두번째) KB국민은행 여신그룹 부행장이 26일(현지시간) 영국 런던 ...
# 23   KB국민은행은 26일 KB국민은행 천안연수원에서 'KB굿잡 취업학교 제7기' 입학식...
# 24   KB국민은행은 26일 KB국민은행 천안연수원에서 ‘KB굿잡 취업학교 제7기’ 입학식...
# 25   KB국민은행은 26일부터 'KB굿잡 취업학교 제7기'를 운영한다고 밝혔다. 이번 프...
# 26   KB국민은행은 연금 대표상품인 타겟데이트펀드(TDF) 가입고객을 대상으로 오는 5월...
# 27   연금저축펀드 가입고객에 모바일 커피쿠폰 등[아이뉴스24 허인혜 기자] KB국민은행은...
# 28   허인(오른쪽 세번째)KB국민은행장이 지난해 5월 서울 코엑스에서 열린 ‘2018 K...
# 29   KB국민은행이 연금 상품인 TDF 가입 이벤트를 오는 5월 말까지 진행한다. 제공 ...
# ..                                                 ...
# 270  [스포츠서울 황철훈기자] KB국민은행은 5일, 인터넷뱅킹과 스타뱅킹의 펀드 및 보험...
# 271  【서울=뉴시스】이영환 기자 = KB국민은행 총파업 예정일을 하루 앞둔 7일 오전 서...
# 272  【서울=뉴시스】이영환 기자 = 7일 오전 서울 영등포구 여의도 KB국민은행 본점에 ...
# 273  【서울=뉴시스】이영환 기자 = 7일 오전 서울 영등포구 여의도 KB국민은행 본점에 ...
# 274  사측, 성과급 등에서 물러섰지만 파업진행기본급 300%면 최대 1200만원 받는 셈...
# 275  개인대출·외환·기업금융·콜센터 이용 대부분 '스톱'사측 비상대책계획 수립중…지점장 ...
# 276  【서울=뉴시스】이영환 기자 = 7일 오전 서울 영등포구 여의도 KB국민은행 본점에 ...
# 277  【서울=뉴시스】이영환 기자 = 7일 오전 서울 영등포구 여의도 KB국민은행 본점에 ...
# 278  [ 윤상연 기자  ] 이민우(사진 왼쪽) 경기신보 이사장은 1일 최성훈 KB국민은행...
# 279  KB국민은행이 임금피크 전환ㆍ예정자를 대상으로 실시한 희망퇴직에 600명이 넘는 신...
# 280  [아시아경제 박철응 기자] KB국민은행 희망퇴직에 600여명이 몰렸다. 지난해의 1...
# 281  (서울=뉴스1) 이종덕 기자 = KB국민은행 노조가 총파업에 나선 8일 오후 서울 ...
# 282  중노위 사후조정 통해 잠정합의…임단협 돌입 99일 만에 도출25일 조합원 찬반투표로...
# 283  (서울=뉴스1) 이종덕 기자 = KB국민은행 노조가 총파업에 나선 8일 오후 서울 ...
# 284  (서울=뉴스1) 이종덕 기자 = KB국민은행 노조가 총파업에 나선 8일 오후 서울 ...
# 285  (서울=뉴스1) 이종덕 기자 = KB국민은행 노조가 총파업에 나선 8일 오후 서울 ...
# 286  [서울경제] 3·1운동 100주년 및 대한민국 임시정부 수립 100주년을 맞아 지난...
# 287  [한국경제TV 고영욱 기자]KB국민은행 전 경영진이 4일 오후 허인 국민은행장에게 ...
# 288  KB국민은행 전 경영진은 8일 예정된 파업으로 인해 영업이 정상적으로 수행되지 못할...
# 289  부점장급 66년 이전 출생, 팀장·직원급 65년 이전 출생 대상최대 39개월치 특별...
# 290  KB국민은행은은 이달 11일부터 14일까지 임금피크 직원을 대상으로 희망퇴직 신청을...
# 291  KB국민은행 노조가 집중교섭을 사측에 제안했다고 11일 밝혔다. 노조 측은 13일까...
# 292  4분기 당기순이익은 일회성 비용 증가로 1천450억원 기록[아이뉴스24 유재형 기자...
# 293  【서울=뉴시스】천민아 기자 = 박홍배 KB국민은행 노조위원장(왼쪽)과 허권 전국금융...
# 294  파업시 3000만 고객 불편 불가피[서울신문]국민은행 파업을 하루 앞둔 7일 서울 ...
# 295  【서울=뉴시스】조현아 기자 = KB국민은행은 서울 광진구청에 지점을 열고 본격적인 ...
# 296  ◆…KB국민은행이 5월말까지 환전 페스티벌을 실시한다. 사진=KB국민은행 제공KB국...
# 297  KB국민은행이 오는 5월말까지 ‘KB 러빙 홈(Loving Home)’ 환전 페스티...
# 298  KB국민은행 노조가 오늘(8일) 총파업을 예고한 가운데 노사 간 최종 협상이 진행되...
# 299                                      동영상 뉴스
#
# [300 rows x 4 columns]

# %%
with sqlite3.connect('kb1.db') as conn:
    cur=conn.cursor() #커서는 하나씩 일을해나가는것
    sql= 'create table kb1(Date integer primary key,Company varchar(100), Title varchar(200),Content varchar(10000))'
    cur.execute(sql)
    conn.commit() #커밋
    cur.close()#ex)신한은행 홈페이지에서 나오는 클라이언트들의 반응을 뽑아서 분석하고 정제하여 앞으로 나아가야할 인사이트를 알아내겠다.

# %%
dbname="bank.db"

# %%
def seldb(tcode):
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        sql="""
        select 
        IDX,TITLE,CONTENT,POINT
        from kb
        """
        data=cur.execute(sql).fetchall()
        xdata=[]
        ydata=[]
        i=0
        for d in data:
            xdata.append(i)
            ydata.append(d[2])
            i+=1
            #print(d,end="\n")
        conn.commit()
        cur.close()
        return (xdata,ydata)

# %%
hannanum = Hannanum()
kkma = Kkma()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
import matplotlib.font_manager as fm
font_location = 'malgun.ttf'  
#C:\\Users\\Administrator\\Documents\\asiasummer\\webdata\\
font_name = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family = font_name)

print(font_name)
# Out:
# Malgun Gothic

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\programdata\anaconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.16.2)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (5.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#print(df['Content'])
a=df['Content']

# %%
w = WordCloud(
    font_path = 'malgun.ttf',
    width = 1000,
    height = 1000
)
w=w.generate(s)

# %%
plt.imshow(w,interpolation='bilinear')
